# %%
# !pip install playwright
# !playwright install
# Out:
# Requirement already satisfied: playwright in /usr/local/lib/python3.10/dist-packages (1.47.0)
# Requirement already satisfied: greenlet==3.0.3 in /usr/local/lib/python3.10/dist-packages (from playwright) (3.0.3)
# Requirement already satisfied: pyee==12.0.0 in /usr/local/lib/python3.10/dist-packages (from playwright) (12.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pyee==12.0.0->playwright) (4.12.2)
# Playwright Host validation warning:
# ╔══════════════════════════════════════════════════════╗
# ║ Host system is missing dependencies to run browsers. ║
# ║ Missing libraries:                                   ║
# ║     libwoff2dec.so.1.0.2                             ║
# ║     libgstgl-1.0.so.0                                ║
# ║     libgstcodecparsers-1.0.so.0                      ║
# ║     libharfbuzz-icu.so.0                             ║
# ║     libenchant-2.so.2                                ║
# ║     libsecret-1.so.0                                 ║
# ║     libhyphen.so.0                                   ║
# ║     libmanette-0.2.so.0                              ║
# ╚══════════════════════════════════════════════════════╝
#     at validateDependenciesLinux (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/dependencies.js:216:9)
#     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
#     at async Registry._validateHostRequirements (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/index.js:626:43)
#     at async Registry._validateHostRequirementsForExecutableIfNeeded (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/index.js:724:7)
#     at async Registry.validateHostRequirementsForExecutablesIfNeeded (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/server/registry/index.js:713:43)
#     at async t.<anonymous> (/usr/local/lib/python3.10/dist-packages/playwright/driver/package/lib/cli/program.js:119:7)

# %%
import nest_asyncio
import asyncio
from playwright.async_api import async_playwright
import pandas as pd
from google.colab import drive
import time
import re  # 正規表現ライブラリのインポート

# Colabでのイベントループの再利用を可能にする
nest_asyncio.apply()

# URLからコードと歌詞を取得する関数
async def fetch_lyrics_and_chords(url):
    try:
        async with async_playwright() as p:
            # ヘッドレスモードでChromiumブラウザを起動
            browser = await p.chromium.launch(headless=True)
            page = await browser.new_page()

            # タイムアウトを90秒に設定して指定されたURLにアクセス
            await page.goto(url, timeout=90000)

            # ユーザーエージェントをセットする
            await page.set_extra_http_headers({
                'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'
            })

            # preタグ内のすべてのテキストを取得
            pre_tag = await page.query_selector('pre')
            full_text = await pre_tag.inner_text()

            await browser.close()

            # コード部分と歌詞部分を分離
            # ここではコードが大文字アルファベットのみ、またはアルファベットと数字の組み合わせとして認識されると仮定
            # 正規表現でコードのパターンに一致する部分を抽出
            chords = re.findall(r'\b[A-G][#b]?(?:maj|maj7|min|dim|aug|sus|sus2|sus4|add9|m|m7|M7|m/A|7|6|9|13)?\b', full_text)

            chords = [chord for chord in chords if not re.match(r'Capo|\d+', chord)]

            # コード部分を取り除いた歌詞を作成
            lyrics = full_text
            # 「CHORDS:」セクションとそれに続く行を削除
            lyrics = re.sub(r'CHORDS:.*?(?=\n\n|\Z)', '', lyrics, flags=re.DOTALL)
            for chord in chords:
                # コードを歌詞から正確に削除する
                lyrics = re.sub(r'\b' + re.escape(chord) + r'\b', '', lyrics)


            # ギタータブ譜を削除 (行の先頭が e|, B|, G|, D|, A|, E| で始まる行を削除)
            lyrics = re.sub(r'^[eBGDAE]\|.*$', '', lyrics, flags=re.MULTILINE)
            # Intro: の前のテキストを削除
            lyrics = re.sub(r'.*?(?=Intro:)', '', lyrics, flags=re.DOTALL)
            # [Intro]以前のテキストを削除
            lyrics = re.sub(r'.*?(?=\[Intro\])', '', lyrics, flags=re.DOTALL)
            # [Outro]以降のすべてのテキストを削除
            lyrics = re.sub(r'\[Outro.*?\]', '', lyrics)
            lyrics = re.sub(r'Outro.*', '', lyrics)
            # []で囲まれた部分を削除
            lyrics = re.sub(r'\[.*?\]', '', lyrics)
            # Intro:, Verse 1:, Interlude: の削除
            lyrics = re.sub(r'(Intro|Verse \d+|Interlude|Pre-chorus|Chorus \d+|Outro):', '', lyrics)
            # 括弧内のテキストを削除
            lyrics = re.sub(r'\(.*?\)', '', lyrics)
            # ハイフンでつながった数字の部分（3-5-5や8-8）を削除
            lyrics = re.sub(r'\d+-\d+(?:-\d+)?', '', lyrics)
            # ハイフンを削除
            lyrics = lyrics.replace('-', '')
            # 「x4½」などの部分を削除
            lyrics = re.sub(r'x\d+½?', '', lyrics)
            # ピリオドで終わる文を削除
            lyrics = re.sub(r'.*?\.', '', lyrics)
            # "X" を削除
            lyrics = re.sub(r'\bX\b', '', lyrics)
            # "N.C." を削除
            lyrics = re.sub(r'\bN\.C\.\b', '', lyrics)
            # スラッシュ "/" と "|" を削除
            lyrics = re.sub(r'[\/|]', '', lyrics)
            # "#" を削除
            lyrics = re.sub(r'\b#\b', '', lyrics)
            # "%" を削除
            lyrics = re.sub(r'\b%\b', '', lyrics)
            # 数字を削除
            lyrics = re.sub(r'\d+', '', lyrics)
            # 余分なスペースや改行を整える
            lyrics = re.sub(r'\s+', ' ', lyrics).strip()

            return lyrics, ' '.join(chords)
    except Exception as e:
        print(f"Error fetching {url}: {e}")
        return None, None

async def main():
    # Google Driveのマウント
    drive.mount('/content/drive')

    # 曲のURLリストが保存されたテキストファイルのパスを指定
    file_path = '/content/drive/My Drive/music.txt'

    # テキストファイルを開く
    with open(file_path, 'r') as file:
        urls = file.read().splitlines()

    # URL、歌詞、コードのデータを格納するリスト
    data = []

    # 各URLについて、fetch_lyrics_and_chords関数を呼び出して、歌詞とコードを取得する
    for url in urls:
        lyrics, chords = await fetch_lyrics_and_chords(url)

        # 歌詞とコードが取得できた場合、それらをdataリストに追加する
        if lyrics and chords:
            data.append([url, lyrics, chords])
        else:
            print(f"Failed to fetch data for {url}")

    if data:
        # データをDataFrameに変換
        df = pd.DataFrame(data, columns=['URL', 'Lyrics', 'Chords'])

        # CSVファイルに保存
        df.to_csv('/content/drive/My Drive/lyrics_and_chords_separated.csv', index=False, encoding='utf-8')
        print("Data successfully saved to CSV.")
    else:
        print("No data to save.")

# 既存のイベントループで実行
await main()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-8203aef13a10> in <cell line: 128>()
#     126
#     127 # 既存のイベントループで実行
# --> 128 await main()
#
# <ipython-input-10-8203aef13a10> in main()
#      99
#     100     # テキストファイルを開く
# --> 101     with open(file_path, 'r') as file:
#     102         urls = file.read().splitlines()
#     103
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/chords.txt'

# %%
import nest_asyncio
import asyncio
from playwright.async_api import async_playwright
import csv
from google.colab import drive
import re

# Colabでのイベントループの再利用を可能にする
nest_asyncio.apply()

# URLからコードと歌詞を取得する関数
async def fetch_lyrics_and_chords(url):
    try:
        async with async_playwright() as p:
            # ヘッドレスモードでChromiumブラウザを起動
            browser = await p.chromium.launch(headless=True)
            page = await browser.new_page()

            # タイムアウトを90000に設定して指定されたURLにアクセス
            await page.goto(url, timeout=90000)

            # ユーザーエージェントをセットする
            await page.set_extra_http_headers({
                'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'
            })

            # preタグ内のすべてのテキストを取得
            pre_tag = await page.query_selector('pre')
            full_text = await pre_tag.inner_text()

            await browser.close()

            # コード部分と歌詞部分を分離
            chords = re.findall(r'\b[A-G][#b]?(?:maj|maj7|min|dim|aug|sus|sus2|sus4|add9|m|m7|M7|m/A|7|6|9|13)?\b', full_text)
            chords = [chord for chord in chords if not re.match(r'Capo|\d+', chord)]

            # コード部分を取り除いた歌詞を作成
            lyrics = full_text
            lyrics = re.sub(r'CHORDS:.*?(?=\n\n|\Z)', '', lyrics, flags=re.DOTALL)
            for chord in chords:
                lyrics = re.sub(r'\b' + re.escape(chord) + r'\b', '', lyrics)

            # ギタータブ譜や不要な部分を削除
            lyrics = re.sub(r'^[eBGDAE]\|.*$', '', lyrics, flags=re.MULTILINE)
            lyrics = re.sub(r'.*?(?=Intro:)', '', lyrics, flags=re.DOTALL)
            lyrics = re.sub(r'.*?(?=\[Intro\])', '', lyrics, flags=re.DOTALL)
            lyrics = re.sub(r'\[Outro.*?\]', '', lyrics)
            lyrics = re.sub(r'Outro.*', '', lyrics)
            lyrics = re.sub(r'\[.*?\]', '', lyrics)
            lyrics = re.sub(r'(Intro|Verse \d+|Interlude|Pre-chorus|Chorus \d+|Outro):', '', lyrics)
            lyrics = re.sub(r'\(.*?\)', '', lyrics)
            lyrics = re.sub(r'\d+-\d+(?:-\d+)?', '', lyrics)
            lyrics = lyrics.replace('-', '')
            lyrics = re.sub(r'x\d+½?', '', lyrics)
            lyrics = re.sub(r'.*?\.', '', lyrics)
            lyrics = re.sub(r'\bX\b', '', lyrics)
            lyrics = re.sub(r'\bN\.C\.\b', '', lyrics)
            lyrics = re.sub(r'[\/|]', '', lyrics)
            lyrics = re.sub(r'#', '', lyrics)
            lyrics = re.sub(r'\b%\b', '', lyrics)
            lyrics = re.sub(r'\d+', '', lyrics)
            lyrics = re.sub(r'\s+', ' ', lyrics).strip()

            # 歌詞とコードのどちらも取得できるか確認
            status = 1 if lyrics and chords else 0

            return lyrics, ' '.join(chords), status
    except Exception as e:
        print(f"Error fetching {url}: {e}")
        return None, None, 0

async def main():
    # Google Driveのマウント
    drive.mount('/content/drive')

    # 曲のURLリストが保存されたテキストファイルのパスを指定
    file_path = '/content/drive/My Drive/chords.txt'
    output_file = '/content/drive/My Drive/lyrics_and_chords_separated3.csv'

    # CSVファイルにヘッダーを書き込む（ファイルが存在しない場合）
    with open(output_file, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['URL', 'Lyrics', 'Chords', 'Status'])

    # テキストファイルを開く
    with open(file_path, 'r') as file:
        urls = file.read().splitlines()

    # 各URLについて、fetch_lyrics_and_chords関数を呼び出して、歌詞とコードを取得する
    for url in urls:
        lyrics, chords, status = await fetch_lyrics_and_chords(url)

        # 取得したデータをCSVに追加
        with open(output_file, mode='a', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            writer.writerow([url, lyrics, chords, status])

        # ステータスの確認
        if status == 1:
            print(f"Data for {url} saved successfully.")
        else:
            print(f"Failed to fetch data for {url}")

# 既存のイベントループで実行
await main()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Error fetching https://tabs.ultimate-guitar.com/tab/lady-gaga/die-with-a-smile-chords-5389398: Page.goto: Timeout 90000ms exceeded.
# Call log:
# navigating to "https://tabs.ultimate-guitar.com/tab/lady-gaga/die-with-a-smile-chords-5389398", waiting until "load"
#
# Failed to fetch data for https://tabs.ultimate-guitar.com/tab/lady-gaga/die-with-a-smile-chords-5389398
# Data for https://tabs.ultimate-guitar.com/tab/gigi-perez/sailor-song-chords-5363001 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/gracie-abrams/i-love-you-im-sorry-chords-5315181 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/elvis-presley/cant-help-falling-in-love-chords-1086983 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/radiohead/creep-chords-4169 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/ed-sheeran/perfect-chords-1956589 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/the-cranberries/linger-chords-612578 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/billie-eilish/wildflower-chords-5270925 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/billie-eilish/birds-of-a-feather-chords-5270913 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/eagles/hotel-california-chords-46190 saved successfully.
# Error fetching https://tabs.ultimate-guitar.com/tab/vance-joy/riptide-chords-1237247: Page.goto: Timeout 90000ms exceeded.
# Call log:
# navigating to "https://tabs.ultimate-guitar.com/tab/vance-joy/riptide-chords-1237247", waiting until "load"
#
# Failed to fetch data for https://tabs.ultimate-guitar.com/tab/vance-joy/riptide-chords-1237247
# Data for https://tabs.ultimate-guitar.com/tab/oasis/wonderwall-chords-27596 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/jeff-buckley/hallelujah-chords-198052 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/coldplay/yellow-chords-114080 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/goo-goo-dolls/iris-chords-54512 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/oasis/dont-look-back-in-anger-chords-6097 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/chappell-roan/good-luck-babe-chords-5191149 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/john-denver/take-me-home-country-roads-chords-1101747 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/coldplay/viva-la-vida-chords-675427 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/the-cranberries/zombie-chords-844902 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/the-animals/house-of-the-rising-sun-chords-18688 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/zach-bryan/something-in-the-orange-chords-4012711 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/pink-floyd/wish-you-were-here-chords-44555 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/noah-kahan/stick-season-chords-4271572 saved successfully.
# Error fetching https://tabs.ultimate-guitar.com/tab/passenger/let-her-go-chords-1137467: Page.goto: Timeout 90000ms exceeded.
# Call log:
# navigating to "https://tabs.ultimate-guitar.com/tab/passenger/let-her-go-chords-1137467", waiting until "load"
#
# Failed to fetch data for https://tabs.ultimate-guitar.com/tab/passenger/let-her-go-chords-1137467
# Data for https://tabs.ultimate-guitar.com/tab/adele/someone-like-you-chords-1006751 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/misc-soundtrack/a-star-is-born-shallow-chords-2488086 saved successfully.
# Error fetching https://tabs.ultimate-guitar.com/tab/john-denver/take-me-home-country-roads-chords-57606: Page.goto: Timeout 90000ms exceeded.
# Call log:
# navigating to "https://tabs.ultimate-guitar.com/tab/john-denver/take-me-home-country-roads-chords-57606", waiting until "load"
#
# Failed to fetch data for https://tabs.ultimate-guitar.com/tab/john-denver/take-me-home-country-roads-chords-57606
# Data for https://tabs.ultimate-guitar.com/tab/grover-washington-jr-/just-the-two-of-us-chords-663141 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/bruno-mars/when-i-was-your-man-chords-1198871 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/keane/somewhere-only-we-know-chords-109970 saved successfully.
# Error fetching https://tabs.ultimate-guitar.com/tab/green-day/good-riddance-time-of-your-life-chords-12835: Page.goto: Timeout 90000ms exceeded.
# Call log:
# navigating to "https://tabs.ultimate-guitar.com/tab/green-day/good-riddance-time-of-your-life-chords-12835", waiting until "load"
#
# Failed to fetch data for https://tabs.ultimate-guitar.com/tab/green-day/good-riddance-time-of-your-life-chords-12835
# Data for https://tabs.ultimate-guitar.com/tab/misc-soundtrack/barbie-what-was-i-made-for-chords-4871180 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/creedence-clearwater-revival/have-you-ever-seen-the-rain-chords-56479 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/the-beatles/hey-jude-chords-1061739 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/frank-sinatra/fly-me-to-the-moon-chords-335196 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/the-beatles/yesterday-chords-17450 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/pixies/where-is-my-mind-chords-89446 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/bob-dylan/knockin-on-heavens-door-chords-66559 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/ed-sheeran/photograph-chords-1493446 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/green-day/boulevard-of-broken-dreams-chords-146744 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/dolly-parton/jolene-chords-183019 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/the-beatles/let-it-be-chords-60690 saved successfully.
# Error fetching https://tabs.ultimate-guitar.com/tab/john-lennon/imagine-chords-9306: Page.goto: Timeout 90000ms exceeded.
# Call log:
# navigating to "https://tabs.ultimate-guitar.com/tab/john-lennon/imagine-chords-9306", waiting until "load"
#
# Failed to fetch data for https://tabs.ultimate-guitar.com/tab/john-lennon/imagine-chords-9306
# Data for https://tabs.ultimate-guitar.com/tab/ben-e-king/stand-by-me-chords-1724608 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/4-non-blondes/whats-up-chords-349210 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/bethel-music/goodness-of-god-chords-2423013 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/chris-isaak/wicked-game-chords-11066 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/sixpence-none-the-richer/kiss-me-chords-2707 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/nirvana/smells-like-teen-spirit-chords-807883 saved successfully.
# Error fetching https://tabs.ultimate-guitar.com/tab/simon-garfunkel/the-sound-of-silence-chords-159157: Page.goto: Timeout 90000ms exceeded.
# Call log:
# navigating to "https://tabs.ultimate-guitar.com/tab/simon-garfunkel/the-sound-of-silence-chords-159157", waiting until "load"
#
# Failed to fetch data for https://tabs.ultimate-guitar.com/tab/simon-garfunkel/the-sound-of-silence-chords-159157
# Data for https://tabs.ultimate-guitar.com/tab/lewis-capaldi/someone-you-loved-chords-2512737 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/stephen-sanchez/until-i-found-you-chords-3860363 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/tom-odell/another-love-chords-1198980 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/taylor-swift/love-story-chords-730809 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/lord-huron/the-night-we-met-chords-1709964 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/chappell-roan/pink-pony-club-chords-3066623 saved successfully.
# Error fetching https://tabs.ultimate-guitar.com/tab/adele/make-you-feel-my-love-chords-752102: Page.goto: Timeout 90000ms exceeded.
# Call log:
# navigating to "https://tabs.ultimate-guitar.com/tab/adele/make-you-feel-my-love-chords-752102", waiting until "load"
#
# Failed to fetch data for https://tabs.ultimate-guitar.com/tab/adele/make-you-feel-my-love-chords-752102
# Data for https://tabs.ultimate-guitar.com/tab/radiohead/no-surprises-chords-183884 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/johnny-cash/hurt-chords-89849 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/justin-bieber/love-yourself-chords-1780199 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/coldplay/sparks-chords-394880 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/billy-joel/piano-man-chords-1051336 saved successfully.
# Error fetching https://tabs.ultimate-guitar.com/tab/hozier/too-sweet-chords-5194038: Page.goto: Timeout 90000ms exceeded.
# Call log:
# navigating to "https://tabs.ultimate-guitar.com/tab/hozier/too-sweet-chords-5194038", waiting until "load"
#
# Failed to fetch data for https://tabs.ultimate-guitar.com/tab/hozier/too-sweet-chords-5194038
# Data for https://tabs.ultimate-guitar.com/tab/darius-rucker/wagon-wheel-chords-1215756 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/amy-winehouse/back-to-black-chords-467281 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/the-neighbourhood/sweater-weather-chords-1237978 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/misc-soundtrack/a-star-is-born-always-remember-us-this-way-chords-2484211 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/benson-boone/beautiful-things-chords-5110429 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/cage-the-elephant/cigarette-daydreams-chords-1423735 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/fleetwood-mac/landslide-chords-989772 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/john-legend/all-of-me-chords-1432996 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/richy-mitch-the-coal-miners/evergreen-chords-4654205 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/jason-mraz/im-yours-chords-373896 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/leonard-cohen/hallelujah-chords-64977 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/daniel-caesar/best-part-chords-2126075 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/sixpence-none-the-richer/kiss-me-chords-2704 saved successfully.
# Error fetching https://tabs.ultimate-guitar.com/tab/john-legend/all-of-me-chords-1248578: Page.goto: Timeout 90000ms exceeded.
# Call log:
# navigating to "https://tabs.ultimate-guitar.com/tab/john-legend/all-of-me-chords-1248578", waiting until "load"
#
# Failed to fetch data for https://tabs.ultimate-guitar.com/tab/john-legend/all-of-me-chords-1248578
# Data for https://tabs.ultimate-guitar.com/tab/shaboozey/a-bar-song-tipsy-chords-5223882 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/sabrina-carpenter/taste-chords-5397885 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/ed-sheeran/thinking-out-loud-chords-1486860 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/zach-bryan/i-remember-everything-chords-4928905 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/lizzy-mcalpine/ceilings-chords-3645968 saved successfully.
# Error fetching https://tabs.ultimate-guitar.com/tab/mazzy-star/fade-into-you-chords-945178: Page.goto: Timeout 90000ms exceeded.
# Call log:
# navigating to "https://tabs.ultimate-guitar.com/tab/mazzy-star/fade-into-you-chords-945178", waiting until "load"
#
# Failed to fetch data for https://tabs.ultimate-guitar.com/tab/mazzy-star/fade-into-you-chords-945178
# Data for https://tabs.ultimate-guitar.com/tab/sabrina-carpenter/please-please-please-chords-5299629 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/bill-withers/aint-no-sunshine-chords-468744 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/the-beatles/let-it-be-chords-17427 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/coldplay/fix-you-chords-1863305 saved successfully.
# Error fetching https://tabs.ultimate-guitar.com/tab/2135261: Page.goto: Timeout 90000ms exceeded.
# Call log:
# navigating to "https://tabs.ultimate-guitar.com/tab/2135261", waiting until "load"
#
# Failed to fetch data for https://tabs.ultimate-guitar.com/tab/2135261
# Data for https://tabs.ultimate-guitar.com/tab/oasis/wonderwall-chords-39144 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/billy-joel/vienna-chords-804911 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/creedence-clearwater-revival/bad-moon-rising-chords-15892 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/david-bowie/space-oddity-chords-105869 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/christina-perri/a-thousand-years-chords-1101795 saved successfully.
# Error fetching https://tabs.ultimate-guitar.com/tab/chris-stapleton/tennessee-whiskey-chords-1741042: Page.goto: Timeout 90000ms exceeded.
# Call log:
# navigating to "https://tabs.ultimate-guitar.com/tab/chris-stapleton/tennessee-whiskey-chords-1741042", waiting until "load"
#
# Failed to fetch data for https://tabs.ultimate-guitar.com/tab/chris-stapleton/tennessee-whiskey-chords-1741042
# Data for https://tabs.ultimate-guitar.com/tab/r-e-m-/losing-my-religion-chords-114345 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/billie-eilish/happier-than-ever-chords-3592094 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/coldplay/the-scientist-chords-42050 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/elton-john/your-song-chords-29113 saved successfully.
# Data for https://tabs.ultimate-guitar.com/tab/radiohead/karma-police-chords-103398 saved successfully.
